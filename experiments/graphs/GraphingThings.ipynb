# %%
import matplotlib.pyplot as plt
plt.plot([10,20, 28, 51, 
          56, 75, 92, 118, 132, 175,235, 258, 433, 480], [54, 56, 58, 61, 
                             62, 64, 66, 68, 69, 71, 71, 72, 79, 83])
plt.ylabel('some numbers')
plt.show()
